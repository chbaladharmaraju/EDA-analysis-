# %% [markdown]
# <a href="https://colab.research.google.com/github/chbaladharmaraju/EDA-analysis-/blob/main/Ats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.5 MB/s eta 0:00:00
# ...

# %%
from google import genai
import PyPDF2 as pdf

# %%
client=genai.Client(api_key='AIzaSyCuKdasFOybJxJnyW')

# %%
pdf_path='/content/chbaladharmaraju_resume.pdf'

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extracts text from all pages of a PDF file.
    """
    extracted_text = ""

    with open(pdf_path, "rb") as file:
        reader = pdf.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text

# %%
pdf_text = extract_text_from_pdf(pdf_path)

# %%
job=input("enter job description:")
# Out:
# enter job description:Full stack developer

# %%
Response=client.models.generate_content(
    model='gemini-2.5-flash',
    contents={f'this my resume {pdf_text} and the job descrition is{job},Give the ATS score .'},
)

# %%
print(Response.text)
# Out:
# Okay, Bala DharmaRaju Chinta, let's break down your resume for a "Full Stack Developer" role and give you an ATS score.
#
# **ATS Score: 93/100**
#
# This is an excellent score! Your resume is very well-structured and packed with relevant keywords for a Full Stack Developer position.
#
# ---
#
# ### **ATS Analysis & Feedback**
#
# **Overall Impression:**
# Your resume is highly optimized for a Full Stack Developer role. You've clearly listed relevant skills, demonstrated them through impressive projects, and have a solid educational background. The variety of technologies you've used (React, Django, Node.js, multiple databases) shows strong breadth and practical experience.
#
# ---
#
# **Strengths for a Full Stack Developer Role:**
#
# 1.  **Comprehensive Skillset:** You've hit all the major points for full-stack development:
#     *   **Frontend:** HTML5, CSS3, JavaScript (ES6+), React.js, Tailwind CSS (Excellent combination).
# ...
